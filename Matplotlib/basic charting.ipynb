# %%
# %matplotlib inline 
from matplotlib import pyplot as plt
plt.plot([1,2,3],[2,5,7]) # here point on graph are (1,2),(2,5),(3,7)
plt.show()

# %%
# %matplotlib inline 
from matplotlib import pyplot as plt
plt.plot([1,2,3],[2,5,7]) # here point on graph are (1,2),(2,5),(3,7)
plt.title("GoSu's Data")
plt.ylabel("This is Y")
plt.xlabel("This is X")
plt.show()

# %%
from matplotlib import pyplot
from matplotlib import style

# %%
style.use("ggplot")
x1 = [1,5,4]
y1 = [23,45,89]
x2 = [3,7,3]
y2 = [5,8,9]
plt.plot(x1,y1,label ="first",linewidth = 3)
plt.plot(x2,y2,label = "Second",linewidth = 5)
plt.legend() # it is used to show label on the graph.
# plt.grid()
plt.show()

# %%
# For Scatter Plot
plt.scatter(x1,y1)
plt.hist(y1)
plt.show()
